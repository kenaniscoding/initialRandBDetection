# %%
import os

dir = 'Dataset' #C:\Users\Kenan\Downloads\CNN_train_test_model\Dataset
items = os.listdir(dir)
items
# Out:
# ['1. Green',
#  '1. Ripe',
#  '1. Semi-Ripe',
#  '2. Green Defect',
#  '2. Ripe Defect',
#  '2. Semi-Ripe Defect']

# %%
#create a new folder that is used to enter the results of the split dataset

# !mkdir datasplit

# %%
#create variables by defining the location of the raw dataset folder and the splitting dataset folder

dataraw = './Dataset'
datasplit = './datasplit'

# %%
#dataset splitting process with a ratio of 70% train data, 20% validation data and 10% test data

# !pip install split-folders
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import splitfolders
splitfolders.ratio(dataraw, output=datasplit, seed=1337, ratio=(.7,.2,.1),group_prefix=None)
# Out:
# Copying files: 576 files [00:11, 50.43 files/s]

# %%
#result splitting dataset

items_splitting = os.listdir(datasplit)
items_splitting
# Out:
# ['test', 'train', 'val']

# %%
# directory list
train_path = './datasplit/train'
test_path = './datasplit/test'
validation_path = './datasplit/val'
items = os.listdir(train_path)
items
# Out:
# ['1. Green',
#  '1. Ripe',
#  '1. Semi-Ripe',
#  '2. Green Defect',
#  '2. Ripe Defect',
#  '2. Semi-Ripe Defect']

# %%
train_dir = []
test_dir = []
validation_dir = []
for item in items :
  train_dir.append(train_path + '/' + item + '/')
  test_dir.append(test_path + '/' + item + '/')
  validation_dir.append(validation_path + '/' + item + '/')

# %%
#Showing an example of a Padang cuisine image dataset

# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2

labels = [(" ").join(x.split('_')) for x in items]

fig = plt.figure(figsize=(20,20))
fig.suptitle("Example of Carabao Mango Dataset", fontsize=24)
i = 1
for path in train_dir :
  for j in range(2) :
    img = mpimg.imread(path+os.listdir(path)[j])
    size = min(img.shape[0], img.shape[1])
    img = cv2.resize(img, (size,size))
    plt.subplot(6,6,i)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(img, cmap=plt.cm.binary)
    plt.xlabel(labels[int((i-1)/2)], fontsize=15)
    i += 1
plt.show()
